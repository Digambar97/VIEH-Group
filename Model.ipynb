# %%
import pandas as pd
data = pd.read_csv("/drive/notebooks/CreditCardData.csv")
data.head()
# Out:
#   card  reports       age  income     share  expenditure owner selfemp  \
# 0  yes        0  37.66667  4.5200  0.033270   124.983300   yes      no
# 1  yes        0  33.25000  2.4200  0.005217     9.854167    no      no
# 2  yes        0  33.66667  4.5000  0.004156    15.000000   yes      no
# 3  yes        0  30.50000  2.5400  0.065214   137.869200    no      no
# 4  yes        0  32.16667  9.7867  0.067051   546.503300   yes      no
#
#    dependents  months  majorcards  active
# 0           3      54           1      12
# 1           3      34           1      13
# 2           4      58           1       5
# 3           0      25           1       7
# 4           2      64           1       5

# %%
data.isnull().sum
data.dropna()
# Out:
#      card  reports       age  income     share  expenditure owner selfemp  \
# 0     yes        0  37.66667  4.5200  0.033270   124.983300   yes      no
# 1     yes        0  33.25000  2.4200  0.005217     9.854167    no      no
# 2     yes        0  33.66667  4.5000  0.004156    15.000000   yes      no
# 3     yes        0  30.50000  2.5400  0.065214   137.869200    no      no
# 4     yes        0  32.16667  9.7867  0.067051   546.503300   yes      no
# ...   ...      ...       ...     ...       ...          ...   ...     ...
# 1314  yes        0  33.58333  4.5660  0.002146     7.333333   yes      no
# 1315   no        5  23.91667  3.1920  0.000376     0.000000    no      no
# 1316  yes        0  40.58333  4.6000  0.026513   101.298300   yes      no
# 1317  yes        0  32.83333  3.7000  0.008999    26.996670    no     yes
# 1318  yes        0  48.25000  3.7000  0.111619   344.157500   yes      no
#
#       dependents  months  majorcards  active
# 0              3      54           1      12
# 1              3      34           1      13
# 2              4      58           1       5
# 3              0      25           1       7
# 4              2      64           1       5
# ...          ...     ...         ...     ...
# 1314           0      94           1      19
# 1315           3      12           1       5
# 1316           2       1           1       2
# 1317           0      60           1       7
# 1318           2       2           1       0
#
# [1319 rows x 12 columns]

# %%
import matplotlib.pyplot as plt
x = data['dependents']
y = data['months']
# plt.xlabel['dependents']
# plt.ylabel['months']
plt.scatter(x,y)
plt.show()

# %%
import numpy as np
x = np.array(data['dependents']).reshape(-1, 1)
x.shape
y = np.array(data['months'])
y.shape
# Out:
# (1319,)

# %%
print(x)
print(y)
print(type(x))
print(type(y))
# Out:
# [[3]
#  [3]
#  [4]
#  ...
#  [2]
#  [0]
#  [2]]
# [54 34 58 ...  1 60  2]
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.40)
x_train.shape
x_test.shape
y_train.shape
y_test.shape
# print(x_train.shpae)
# print(x_test.shape)
# print(y_train.shpae)
# print(y_test.shape)
# Out:
# (528,)

# %%
from sklearn.linear_model import LinearRegression
clf = LinearRegression()
clf.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
clf.predict(x_test)
clf.score(x_test, y_test)
# Out:
# 0.0026331493957143515

# %%
from sklearn.ensemble import RandomForestClassifier
import pandas as pd

clf = RandomForestClassifier()
clf.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
clf.predict(x_test)
clf.score(x_test, y_test)
# Out:
# 0.07007575757575757

# %%
from sklearn import metrics

print("ACCURACY OF THE MODEL: ", metrics.accuracy_score(x_train, y_train))
# Out:
# ACCURACY OF THE MODEL:  0.0037926675094816687
